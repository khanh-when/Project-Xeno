# %%
import yfinance as yf
import pandas as pd

# %%
tick = 'NVDA'

# %%
nvda = yf.download(tick, start ='2020-1-1', end='2025-10-31')
# Out:
# /tmp/ipykernel_995004/3502552181.py:1: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   nvda = yf.download(tick, start ='2020-1-1', end='2025-10-31')
# [*********************100%***********************]  1 of 1 completed

# %%
nvda.to_csv('nvdea.csv', index=True)
